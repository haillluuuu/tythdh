# %% [markdown]
# <a href="https://colab.research.google.com/github/haillluuuu/tythdh/blob/main/Python_Fundamentals_Canoy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Identation

# %%
if 5 > 2:
  print("Five is Greater than Two!")
# Out:
# Five is Greater than Two!

# %% [markdown]
# Phyton Comments

# %%
#This is a comment
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# Variable Naming Conventions

# %% [markdown]
# Python Variable

# %%
x = 1
a, b=0,-1
a, b, c=0,-1,2

#Others:
b = "Sally" #This is a type of string
print(b)
# Out:
# Sally

# %% [markdown]
# Casting

# %%
b="sally" #This is a type of string
b=int(4)
print(b)

b=float(4)
print(b)
# Out:
# 4
# 4.0

# %% [markdown]
# Typr() Function

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# Double quotes or Single qoutes

# %%
y = "John"
y = 'John'

# %% [markdown]
# Case sensitive

# %%
a = 4
A = "Sally"
#A will not  overwrite a

# %% [markdown]
# Multiple Variables

# %%
x, y, z = "one", "two", "three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %% [markdown]
# One Value Variables

# %%
x = y = z = "four"
print(x)
print(y)
print(z)
# Out:
# four
# four
# four

# %% [markdown]
# Output Variables

# %%
x = "enjoying"
print("Phyton programing is " + x)
# Out:
# Phyton programing is enjoying

# %%
#Another Way is

x = "Phyton is "
y = "enjoying"
z = x + y

print(z)
# Out:
# Phyton is enjoying

# %% [markdown]
# Arithmetic Operations

# %%
x = 5
y = 3
print (x + y)

# %%
#Ways in using Arithmetic operations

#Addition

x = 5
y = 3
sum = x + y
sum

#Subtraction

a = 5
b = 3
sum1 = a - b
sum1

#multiplication

c = 5
d = 3
sum2 = c * d
sum2

#division

e = 5
f = 3
sum3 = e / f
sum3

#modulus

g = 5
h = 3
sum4 = g % h
sum4

#Exponentiation

l = 5
m = 3
sum5 = l ** m
sum5

#Floor Division

o = 5
p = 3
sum6 = o // p
sum6
# Out:
# 1

# %% [markdown]
# Assignment Operators

# %%
s = 1
s += 3

print(s)
# Out:
# 4

# %%
s = 1
s -= 3

print(s)
# Out:
# -2

# %%
s = 1
s *=3

print(s)

# %%
s = 1
s /= 3

print(s)
# Out:
# 0.3333333333333333

# %%
s = 1
s %= 3

print(s)
# Out:
# 1

# %%
s = 1
s //= 3

print(s)

# %%
s = 1
s **= 3

print(s)

# %%
s = 1
s &= 3

print(s)

# %%
s = 1
s |= 3

print(s)

# %%
s = 1
s ^= 3

print(s)
# Out:
# 2

# %%
s = 1
s >>= 3

print(s)
# Out:
# 0

# %% [markdown]
# Comparison Operators

# %%
t = 1
u = 2

t == u
# Out:
# True

# %%
t = 1
u = 2

t != u

# %%
t = 1
u = 2

t > u

# %%
t = 1
u = 2

t < u

# %%
t = 1
u = 2

t >= u
# Out:
# False

# %%
t = 1
u = 2

t <= u
# Out:
# True

# %% [markdown]
# Logical Operations

# %%
t = 1
u = 2

t > 5 and x < 10
# Out:
# False

# %%
t = 1
u = 2

t < 5 or t < 4
# Out:
# True

# %% [markdown]
#   Identity Operations

# %%
t = 1
u = 2

t is u
# Out:
# False

# %%
t = 1
u = 2

t is not u
# Out:
# True

# %% [markdown]
# Bitwise Operators

# %%
v = 2

v << 2
# Out:
# 8

# %%
15 & 15
# Out:
# 15
